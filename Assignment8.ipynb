# %% [markdown]
# <a href="https://colab.research.google.com/github/emad550/ML/blob/master/Assignment8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this assignment students have to transform iris data into 3 dimensions
# and plot a 3d chart with transformed dimensions and colour each data
# point with specific class.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn import datasets
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA

# %%
#import data iris
data=sns.load_dataset('iris')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
X=data.iloc[:,0:-1]
y=data.iloc[:,-1]

# %%
#convert y to categorical 
label=LabelEncoder()
y=label.fit_transform(y)

# %%
# convert X to 3 dimension 
pca=PCA(n_components=3)
X=pca.fit_transform(X)

# %%
fig = plt.figure(figsize=(4, 3))
ax = Axes3D(fig=fig)
ax.scatter(X[:,0], X[:,1], X[:,2], c=y, edgecolor='k')
plt.show()
